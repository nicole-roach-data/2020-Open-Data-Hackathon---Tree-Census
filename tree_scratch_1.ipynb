# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', 300)
from collections import Counter

# %%
df_95 = pd.read_csv('1995_Street_Tree_Census.csv')

# %%
df_05 = pd.read_csv('2005_Street_Tree_Census.csv', low_memory=False)

# %%
df_15 = pd.read_csv('2015StreetTreesCensus_TREES.csv')

# %%
## Trees 95

# %%
df_95.head(4)
# Out:
#    RecordId        Address  House_Number      Street  Postcode_Original  \
# 0         1    245 E 17 ST         245.0     E 17 ST              10003
# 1         2  80 N MOORE ST          80.0  N MOORE ST              10013
# 2         3  80 N MOORE ST          80.0  N MOORE ST              10013
# 3         4  80 N MOORE ST          80.0  N MOORE ST              10013
#
#    Community Board_Original   Site Species  Diameter  Condition Wires  \
# 0                       106  Front    PLAC         8    Unknown  None
# 1                       101   Side    ACPL         7       Good  None
# 2                       101   Side    ACPL         6       Good  None
# 3                       101   Side    ACPL         7  Excellent  None
#
#   Sidewalk_Condition Support_Structure    Borough            X            Y  \
# 0                NaN              None  Manhattan  988618.9688  206893.7640
# 1               Good              None  Manhattan  981330.4271  201649.9518
# ...

# %%
df_95.Borough.unique()
# Out:
# array(['Manhattan', 'Bronx', 'Brooklyn', 'Queens', 'Staten Island'],
#       dtype=object)

# %%
pd.value_counts(df_95['Condition'])
# Out:
# Good              332562
# Excellent         100286
# Poor               38571
# Planting Space     15231
# Dead               12859
# Unknown            10761
# Stump               6087
# Fair                 327
# Shaft                303
# Critical               2
# Name: Condition, dtype: int64

# %%
species_95 = list(df_95.Spc_Common.unique())

# %%
len(species_95)
# Out:
# 276

# %%
df_95_species = pd.DataFrame(pd.value_counts(df_95['Spc_Common']))

# %%
df_95_sci = pd.DataFrame(pd.value_counts(df_95['Spc_Latin']))

# %%
len(df_95_species)
# Out:
# 276

# %%
len(df_95_sci)
# Out:
# 263

# %%
df_95_species.head(276)
# Out:
#                       Spc_Common
# MAPLE, NORWAY             109321
# LONDON PLANETREE           88040
# OAK, PIN                   36553
# HONEYLOCUST                33727
# PEAR, CALLERY              31293
# LINDEN, LITTLE LEAF        26489
# MAPLE, SILVER              22347
# MAPLE, RED                 17993
# ASH, GREEN                 17684
# MAPLE, SUGAR               15355
# PLANTING SITE              15231
# GINKGO                     13758
# UNKNOWN LIVE TREES         10944
# JAPANESE PAGODA TREE        8581
# MAPLE, SYCAMORE             7592
# UNKNOWN DEAD TREES          6833
# OAK, NORTHERN RED           6713
# SWEETGUM                    6671
# ELM, AMERICAN               6057
# ZELKOVA, JAPANESE           5740
# UNKNOWN STUMP               4165
# CHERRY, CORNELIAN           2592
# TREE OF HEAVEN              2476
# OAK, WILLOW                 1964
# PINE, OTHER                 1363
# STUMP                       1232
# EASTERN HOP HORNBEAM        1104
# ...

# %%
df_95_sci.head(263)
# Out:
#                               Spc_Latin
# ACER PLATANOIDES                 109325
# PLATANUS ACERIFOLIA               88040
# QUERCUS PALUSTRIS                 36553
# GLEDITSIA TRIACANTHOS             33727
# PYRUS CALLERYANA                  31295
# TILIA CORDATA                     26489
# ACER SACCHARINUM                  22347
# ACER RUBRUM                       18000
# FRAXINUS PENNSYLVANICA            17685
# ACER SACCHARUM                    15363
# PLANTING SITE                     15231
# GINKGO BILOBA                     13758
# UNKNOWN LIVE TREES                10944
# SOPHORA JAPONICA                   8581
# ACER PSEUDOPLATANUS                7592
# UNKNOWN DEAD TREES                 6833
# QUERCUS RUBRA                      6713
# LIQUIDAMBAR STYRACIFLUA            6671
# ULMUS AMERICANA                    6057
# ZELKOVA SERRATA                    5740
# UNKNOWN STUMP                      3388
# CORNUS MAS                         2592
# ...

# %%
df_95_bk = df_95[df_95.Borough == 'Brooklyn']

# %%
species_95_bk = list(df_95_bk.Spc_Common.unique())

# %%
len(species_95_bk)
# Out:
# 187

# %%
df_95_bx = df_95[df_95.Borough == 'Bronx']

# %%
species_95_bx = list(df_95_bx.Spc_Common.unique())

# %%
len(species_95_bx)
# Out:
# 148

# %%
df_95_si = df_95[df_95.Borough == 'Staten Island']

# %%
species_95_si = list(df_95_si.Spc_Common.unique())

# %%
len(species_95_si)
# Out:
# 126

# %%
df_95_qn = df_95[df_95.Borough == 'Queens']

# %%
species_95_qn = list(df_95_qn.Spc_Common.unique())

# %%
len(species_95_qn)
# Out:
# 178

# %%
df_95_mn = df_95[df_95.Borough == 'Manhattan']

# %%
species_95_mn = list(df_95_mn.Spc_Common.unique())

# %%
len(species_95_mn)
# Out:
# 85

# %%
## Trees 2005

# %%
df_05.head(2)
# Out:
#    OBJECTID  cen_year  tree_dbh             address tree_loc      pit_type  \
# 0    592373      2005         6      1139 57 STREET    Front  Sidewalk Pit
# 1    592374      2005         6  2220 BERGEN AVENUE   Across  Sidewalk Pit
#
#   soil_lvl status            spc_latin        spc_common vert_other vert_pgrd  \
# 0    Level   Good     PYRUS CALLERYANA     PEAR, CALLERY         No        No
# 1    Level   Good  PLATANUS ACERIFOLIA  LONDON PLANETREE         No        No
#
#   vert_tgrd vert_wall horz_blck horz_grate horz_plant horz_other sidw_crack  \
# 0        No        No        No         No        Yes         No         No
# 1        No        No        No         No         No         No         No
#
#   sidw_raise wire_htap wire_prime wire_2nd wire_other inf_canopy inf_guard  \
# 0         No        No        Yes       No         No         No        No
# 1         No        No         No       No         No         No        No
#
# ...

# %%
df_05.boroname.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Bronx', 'Queens', '5', 5], dtype=object)

# %%
df_05.spc_common.unique()
# Out:
# array(['PEAR, CALLERY', 'LONDON PLANETREE', 'MAPLE, NORWAY-CR KNG',
#        'HAWTHORN, OTHER', 'MAPLE, NORWAY', 'HONEYLOCUST',
#        'LINDEN, LITTLE LEAF', 'UNKNOWN', 'GINKGO', 'GOLDENRAIN TREE',
#        'DOGWOOD, FLOWERING', 'MAPLE, SYCAMORE', 'MAPLE, RED',
#        'PLUM, PURPLELEAF', 'ZELKOVA, JAPANESE', 'OAK, PIN', 'ASH, GREEN',
#        'JAPANESE TREE LILAC', 'CHERRY, OTHER', 'MAPLE, AMUR',
#        'JAPANESE PAGODA TREE', 'KATSURA TREE', 'OAK, NORTHERN RED',
#        'Unknown Dead', 'ELM, AMERICAN', 'ELM, CHINESE', 'LINDEN, SILVER',
#        'OAK, WHITE', 'LINDEN, AMERICAN', 'OAK, SWAMP WHITE',
#        'TREE OF HEAVEN', 'DAWN REDWOOD', 'OAK, SAWTOOTH', 'BLACK LOCUST',
#        'OAK, WILLOW', 'HORNBEAM, AMERICAN', 'REDBUD, EASTERN',
#        'KENTUCKY COFFEETREE', 'CHOKECHERRY, SHUBERT', 'MAPLE, SILVER',
#        'HACKBERRY', 'BALDCYPRESS', 'HORNBEAM, EUROPEAN', 'POPLAR, OTHER',
#        'MAPLE, HEDGE', 'MULBERRY', 'ELM, OTHER', 'MAPLE, JAPANESE',
# ...

# %%
acn_sn = df_05.drop_duplicates('spc_common')

# %%
acn_sn.head()
# Out:
#     OBJECTID  cen_year  tree_dbh             address tree_loc        pit_type  \
# 0     592373      2005         6      1139 57 STREET    Front    Sidewalk Pit
# 1     592374      2005         6  2220 BERGEN AVENUE   Across    Sidewalk Pit
# 2     592375      2005        13  2360 BERGEN AVENUE    Front  Continuous Pit
# 9     592382      2005         3      1163 57 STREET    Front            Lawn
# 14    592387      2006        10      5702 12 AVENUE     Side    Sidewalk Pit
#
#    soil_lvl status                               spc_latin  \
# 0     Level   Good                        PYRUS CALLERYANA
# 1     Level   Good                     PLATANUS ACERIFOLIA
# 2     Level   Good  ACER PLATANOIDES          CRIMSON KING
# 9     Level   Good                       CRATAEGUS SPECIES
# 14    Level   Poor                        ACER PLATANOIDES
#
#               spc_common vert_other vert_pgrd vert_tgrd vert_wall horz_blck  \
# ...

# %%
acn_sn = acn_sn[['spc_common', 'spc_latin']]

# %%
acn_sn.to_csv(r'species_asis_05.csv')

# %%
unique_05 = pd.DataFrame(df_05['spc_common'].unique())

# %%
unique_05.shape
# Out:
# (169, 1)

# %%
spc_latin

# %%
df_05_bk = df_05[df_05.boroname == 'Brooklyn']

# %%
species_05_bk = list(df_05_bk.spc_common.unique())

# %%
len(species_05_bk)
# Out:
# 140

# %%
df_05_si = df_05[(df_05.boroname == '5') | (df_05.boroname == 5)]

# %%
species_05_si = list(df_05_si.spc_common.unique())

# %%
len(species_05_si)
# Out:
# 134

# %%
df_05_bx = df_05[df_05.boroname == 'Bronx']

# %%
species_05_bx = list(df_05_bx.spc_common.unique())

# %%
len(species_05_bx)
# Out:
# 121

# %%
df_05_qn = df_05[df_05.boroname == 'Queens']

# %%
species_05_qn = list(df_05_qn.spc_common.unique())

# %%
len(species_05_qn)
# Out:
# 157

# %%
df_05_mn = df_05[df_05.boroname == 'Manhattan']

# %%
species_05_mn = list(df_05_mn.spc_common.unique())

# %%
len(species_05_mn)
# Out:
# 91

# %%
## Trees 2015

# %%
df_15.head(4)
# Out:
#    created_at  tree_id  block_id  \
# 0  08/27/2015   180683    348711
# 1  09/03/2015   200540    315986
# 2  09/05/2015   204026    218365
# 3  09/05/2015   204337    217969
#
#                                         the_geom  tree_dbh  stump_diam  \
# 0  POINT (-73.84421521958048 40.723091773924274)         3           0
# 1   POINT (-73.81867945834878 40.79411066708779)        21           0
# 2  POINT (-73.93660770459083 40.717580740099116)         3           0
# 3  POINT (-73.93445615919741 40.713537494833226)        10           0
#
#   curb_loc status health                           spc_latin   spc_common  \
# 0   OnCurb  Alive   Fair                         Acer rubrum    red maple
# 1   OnCurb  Alive   Fair                   Quercus palustris      pin oak
# 2   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  honeylocust
# 3   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  honeylocust
#
# ...

# %%
len(df_15)
# Out:
# 683788

# %%
df_15.boroname.unique()
# Out:
# array(['Queens', 'Brooklyn', 'Manhattan', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df_15_bk = df_15[df_15.boroname == 'Brooklyn']

# %%
species_15_bk = list(df_15_bk.spc_common.unique())

# %%
len(species_15_bk)
# Out:
# 133

# %%
df_15_bx = df_15[df_15.boroname == 'Bronx']

# %%
species_15_bx = list(df_15_bx.spc_common.unique())

# %%
len(species_15_bx)
# Out:
# 133

# %%
df_15_qn = df_15[df_15.boroname == 'Queens']

# %%
species_15_qn = list(df_15_qn.spc_common.unique())

# %%
len(species_15_qn)
# Out:
# 133

# %%
df_15_mn = df_15[df_15.boroname == 'Manhattan']

# %%
species_15_mn = list(df_15_mn.spc_common.unique())

# %%
len(species_15_mn)
# Out:
# 129

# %%
df_15_si = df_15[df_15.boroname == 'Staten Island']

# %%
species_15_si = list(df_15_si.spc_common.unique())

# %%
len(species_15_si)
# Out:
# 132

# %%
df = pd.DataFrame({'A': [0, 1, 2, 3, 4],
                   'B': [5, 6, 7, 8, 9],
                   'C': ['a', 'b', 'c', 'd', 'e']})

# %%
df.head()
# Out:
#    A  B  C
# 0  0  5  a
# 1  1  6  b
# 2  2  7  c
# 3  3  8  d
# 4  4  9  e

# %%
df = df.replace(0, 5)

# %%
df.head()
# Out:
#    A  B  C
# 0  5  5  a
# 1  1  6  b
# 2  2  7  c
# 3  3  8  d
# 4  4  9  e

# %%
df = df.replace({'e': 10, 1: 100})

# %%
df.head()
# Out:
#      A  B   C
# 0    5  5   a
# 1  100  6   b
# 2    2  7   c
# 3    3  8   d
# 4    4  9  10
